# %%
import pandas as pd

# %%
#Utilizando pandas

# %%
#importando uma base em csv
db = pd.read_csv('titanic_train.csv');

# %%
#invocando as 5 primeiras linhas
#útil para identificar como as informações estão postas

db.head()

#db.tail() busca as 5 últimas
#traz as 5 últimas e 5 primeiras: display(db)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#traz o número de linhas e colunas
db.shape
# Out:
# (891, 12)

# %%
#informações da base de dados

# %%
db.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#mostrar tipos e valores vazios
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#contar valores vazios por coluna
db.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #Principais conceitos estatísticos

# %%
dados = {
    'x': [1, 2, 2.5, 3, 100] 
}

dados = pd.DataFrame(dados)

# %%
# média
dados.mean()
# Out:
# x    21.7
# dtype: float64

# %%
# contagem
dados.count()
# Out:
# x    5
# dtype: int64

# %%
# mediana
dados.median()
# Out:
# x    2.5
# dtype: float64

# %%
# desvio padrão
dados.std()
# Out:
# x    43.777277
# dtype: float64

# %%
# resumo de todas estatísticas
dados.describe()
# Out:
#                 x
# count    5.000000
# mean    21.700000
# std     43.777277
# min      1.000000
# 25%      2.000000
# 50%      2.500000
# 75%      3.000000
# max    100.000000

# %%
#describe na nossa base
db.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# escolhendo colunas da base
db['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# contagem dos valores
db['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# pegando multiplas colunas
db[['Survived', 'Sex', 'Age']]
# Out:
#      Survived     Sex   Age
# 0           0    male  22.0
# 1           1  female  38.0
# 2           1  female  26.0
# 3           1  female  35.0
# 4           0    male  35.0
# ..        ...     ...   ...
# 886         0    male  27.0
# 887         1  female  19.0
# 888         0  female   NaN
# 889         1    male  26.0
# 890         0    male  32.0
#
# [891 rows x 3 columns]

# %%
# Selecionando Linhas

# %%
# Selecionando as linhas que tem Fare maior que 100
db[db.Fare > 500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
# argumentos lógicos
db.loc[(db.Parch > 1) | (db.SibSp > 1)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 7             8         0       3
# 8             9         1       3
# 13           14         0       3
# 16           17         0       3
# 24           25         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 16                               Rice, Master. Eugene    male   2.0      4
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
#
#     Parch  Ticket     Fare Cabin Embarked
# 7       1  349909  21.0750   NaN        S
# 8       2  347742  11.1333   NaN        S
# 13      5  347082  31.2750   NaN        S
# 16      1  382652  29.1250   NaN        Q
# 24      1  349909  21.0750   NaN        S

# %%
# Filtrar por colunas
db.loc[(db.Parch > 1) | (db.SibSp > 1), ["PassengerId", "Parch", "SibSp"]].head()
# Out:
#     PassengerId  Parch  SibSp
# 7             8      1      3
# 8             9      2      0
# 13           14      5      1
# 16           17      1      4
# 24           25      1      3

# %%
# iloc filtra por indice (30 incluindo ao 40 excluindo)
db.iloc[30:40]
# Out:
#     PassengerId  Survived  Pclass  \
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
#
#                                               Name     Sex   Age  SibSp  \
# 30                        Uruchurtu, Don. Manuel E    male  40.0      0
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                        Glynn, Miss. Mary Agatha  female   NaN      0
# 33                           Wheadon, Mr. Edward H    male  66.0      0
# 34                         Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                  Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                Mamee, Mr. Hanna    male   NaN      0
# ...

# %%
# iloc filtra por indice (30 incluindo ao 40 excluindo), da coluna 4 a 6
db.iloc[30:40, 4:6]
# Out:
#        Sex   Age
# 30    male  40.0
# 31  female   NaN
# 32  female   NaN
# 33    male  66.0
# 34    male  28.0
# 35    male  42.0
# 36    male   NaN
# 37    male  21.0
# 38  female  18.0
# 39  female  14.0

# %%
# Formas de visualização

# %%
import matplotlib.pyplot as plt

# %%
# histograma com os valores de tarifa
db.Fare.hist(bins = 20);

# %%
# gráfico de barras
db.Pclass.value_counts().plot.bar();
